# %%
import multiprocessing
import numpy as np
from PIL import Image
import uuid
import time

# %%
def delabeler(path_tuple):
    '''
    Takes a tuple which consists of original RGB image and the labelIds image
    Generate individually labeled RGB images
    NOTE: The generated file has a random uuid string and the class label joined wiht __ (double underscores)
    as the file name
    '''
    
    root_path = '/ssd_scratch/cvit/dksingh/idd/expanded_images/'
    orig_img_path = path_tuple[0]
    label_img_path = path_tuple[1]
    
    orig_img = Image.open(orig_img_path)
    label_img = Image.open(label_img_path)
    
    uniq_label_ids = set(np.unique(label_img))
    blacklisted_label_ids = {2,5,18,27,28,34,35,36,37,38,39}
    filtered_label_ids = uniq_label_ids - blacklisted_label_ids
    
    
    
    for label_id in filtered_label_ids:
        chosen_label_mask = np.array(label_img) == label_id
        chosen_label_mask_stack = np.stack((chosen_label_mask, chosen_label_mask, chosen_label_mask), axis=-1)
        chosen_label_mask_img = np.array(orig_img) * chosen_label_mask_stack
        
        random_file_name = uuid.uuid1().hex+"__"+str(label_id)+".png"
        
        temp_img = Image.fromarray(chosen_label_mask_img)
        temp_img.save(root_path+random_file_name)
        
#         print(f"saved: {random_file_name}")

# %% [markdown]
# #### To test a sample

# %%
# path_tuple= ('/ssd_scratch/cvit/dksingh/cityscapes/leftImg8bit/train/cologne/cologne_000149_000019_leftImg8bit.png','/ssd_scratch/cvit/dksingh/cityscapes/gtFine/train/cologne/cologne_000149_000019_gtFine_labelIds.png')
# delabeler(path_tuple)

# %% [markdown]
# ### Generate the path list

# %%
def get_label_image_path(img_path):
    return img_path.replace("leftImg8bit","gtFine",1)[0:-15]+"gtFine_labelids.png"

file_pointer = open("./train_imgs_idd_file_list.txt", 'r')
img_path_list = [line.rstrip() for line in file_pointer.readlines()]
list_of_path_tuples = [(img_path, get_label_image_path(img_path)) for img_path in img_path_list]

# %% [markdown]
# ### Start the multiprocessing

# %%
start_time = time.time()
pool = multiprocessing.Pool(processes = multiprocessing.cpu_count())
pool.map(delabeler,list_of_path_tuples)
pool.close()
print(f'Total generation time: {time.time()-start_time} seconds')
# Out:
# saved: 107f482cbba911eaba48ac1f6b21d262__0.pngsaved: 105e5072bba911eab6aaac1f6b21d262__0.png
#
# saved: 10844e4ebba911eaa8e9ac1f6b21d262__0.png
# saved: 107d978ebba911eaa7fbac1f6b21d262__0.png
# saved: 107fde86bba911eaad1cac1f6b21d262__0.pngsaved: 107ea62ebba911eaa5eaac1f6b21d262__0.pngsaved: 107a403ebba911eaaab4ac1f6b21d262__0.png
#
#
# saved: 10807b70bba911eaa393ac1f6b21d262__0.png
# saved: 126dceb0bba911eaa8e9ac1f6b21d262__33.png
# saved: 129bc108bba911eaad1cac1f6b21d262__33.png
# saved: 1207e3acbba911eab6aaac1f6b21d262__33.pngsaved: 108280bebba911eaaba9ac1f6b21d262__0.png
# saved: 12056456bba911eaba48ac1f6b21d262__33.png
#
# saved: 1278f970bba911eaa7fbac1f6b21d262__33.png
# saved: 12a501bebba911eaa5eaac1f6b21d262__32.png
# saved: 10a8f898bba911eaaef0ac1f6b21d262__0.pngsaved: 12aae926bba911eaaab4ac1f6b21d262__33.png
# Process ForkPoolWorker-21:
# Process ForkPoolWorker-27:
# Process ForkPoolWorker-19:
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-11:
# Process ForkPoolWorker-15:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-33:
# Traceback (most recent call last):
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-24:
# Process ForkPoolWorker-25:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-2:
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process ForkPoolWorker-3:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-18:
# Process ForkPoolWorker-30:
# Traceback (most recent call last):
# Process ForkPoolWorker-32:
# Traceback (most recent call last):
# Process ForkPoolWorker-31:
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
# Process ForkPoolWorker-36:
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-34:
# Process ForkPoolWorker-14:
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-7:
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
# AttributeError: '_idat' object has no attribute 'fileno'
# AttributeError: '_idat' object has no attribute 'fileno'
# AttributeError: '_idat' object has no attribute 'fileno'
# AttributeError: '_idat' object has no attribute 'fileno'
# Process ForkPoolWorker-10:
# AttributeError: '_idat' object has no attribute 'fileno'
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# AttributeError: '_idat' object has no attribute 'fileno'
# Traceback (most recent call last):
# AttributeError: '_idat' object has no attribute 'fileno'
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
# AttributeError: '_idat' object has no attribute 'fileno'
# Process ForkPoolWorker-22:
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
# Traceback (most recent call last):
# AttributeError: '_idat' object has no attribute 'fileno'
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
#
# During handling of the above exception, another exception occurred:
#
#
# During handling of the above exception, another exception occurred:
#
# Process ForkPoolWorker-35:
#
# During handling of the above exception, another exception occurred:
#
# Process ForkPoolWorker-38:
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
#
# During handling of the above exception, another exception occurred:
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError: '_idat' object has no attribute 'fileno'
# AttributeError: '_idat' object has no attribute 'fileno'
# Process ForkPoolWorker-26:
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
#
# During handling of the above exception, another exception occurred:
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
#   File "<ipython-input-2-e428310e530e>", line 32, in delabeler
#     print(f"saved: {random_file_name}")
# AttributeError: '_idat' object has no attribute 'fileno'
# AttributeError: '_idat' object has no attribute 'fileno'
# AttributeError: '_idat' object has no attribute 'fileno'
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
# Process ForkPoolWorker-40:
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
# AttributeError: '_idat' object has no attribute 'fileno'
# Traceback (most recent call last):
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#
# During handling of the above exception, another exception occurred:
#
# Process ForkPoolWorker-39:
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# AttributeError: '_idat' object has no attribute 'fileno'
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
# Process ForkPoolWorker-17:
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# AttributeError: '_idat' object has no attribute 'fileno'
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel/iostream.py", line 412, in write
#     self.pub_thread.schedule(self._flush)
#
# During handling of the above exception, another exception occurred:
#
#
# During handling of the above exception, another exception occurred:
#
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# AttributeError: '_idat' object has no attribute 'fileno'
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
# AttributeError: '_idat' object has no attribute 'fileno'
# Process ForkPoolWorker-20:
# Traceback (most recent call last):
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-12:
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# Process ForkPoolWorker-37:
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# AttributeError: '_idat' object has no attribute 'fileno'
# AttributeError: '_idat' object has no attribute 'fileno'
# Process ForkPoolWorker-6:
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel/iostream.py", line 207, in schedule
#     f()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#
# During handling of the above exception, another exception occurred:
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# Process ForkPoolWorker-16:
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
# AttributeError: '_idat' object has no attribute 'fileno'
# Process ForkPoolWorker-29:
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-13:
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel/iostream.py", line 384, in _flush
#     parent=self.parent_header, ident=self.topic)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# AttributeError: '_idat' object has no attribute 'fileno'
# Process ForkPoolWorker-23:
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# Process ForkPoolWorker-9:
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/jupyter_client/session.py", line 757, in send
#     stream.send_multipart(to_send, copy=copy)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-2-e428310e530e>", line 30, in delabeler
#     temp_img.save(root_path+random_file_name)
#   File "<ipython-input-2-e428310e530e>", line 30, in delabeler
#     temp_img.save(root_path+random_file_name)
#   File "<ipython-input-2-e428310e530e>", line 30, in delabeler
#     temp_img.save(root_path+random_file_name)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
#   File "<ipython-input-2-e428310e530e>", line 30, in delabeler
#     temp_img.save(root_path+random_file_name)
# AttributeError: '_idat' object has no attribute 'fileno'
# AttributeError: '_idat' object has no attribute 'fileno'
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# AttributeError: '_idat' object has no attribute 'fileno'
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "<ipython-input-2-e428310e530e>", line 30, in delabeler
#     temp_img.save(root_path+random_file_name)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# AttributeError: '_idat' object has no attribute 'fileno'
# AttributeError: '_idat' object has no attribute 'fileno'
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel/iostream.py", line 214, in send_multipart
#     self.schedule(lambda : self._really_send(*args, **kwargs))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-2-e428310e530e>", line 30, in delabeler
#     temp_img.save(root_path+random_file_name)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-2-e428310e530e>", line 30, in delabeler
#     temp_img.save(root_path+random_file_name)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# AttributeError: '_idat' object has no attribute 'fileno'
#   File "<ipython-input-2-e428310e530e>", line 30, in delabeler
#     temp_img.save(root_path+random_file_name)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 510, in _save
#     l, s, d = e.encode(bufsize)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# AttributeError: '_idat' object has no attribute 'fileno'
#   File "<ipython-input-2-e428310e530e>", line 30, in delabeler
#     temp_img.save(root_path+random_file_name)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
#   File "<ipython-input-2-e428310e530e>", line 30, in delabeler
#     temp_img.save(root_path+random_file_name)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/Image.py", line 2134, in save
#     save_handler(self, fp, filename)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/Image.py", line 2134, in save
#     save_handler(self, fp, filename)
# AttributeError: '_idat' object has no attribute 'fileno'
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/Image.py", line 2134, in save
#     save_handler(self, fp, filename)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/Image.py", line 2134, in save
#     save_handler(self, fp, filename)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#
# During handling of the above exception, another exception occurred:
#
#
# During handling of the above exception, another exception occurred:
#
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/Image.py", line 2134, in save
#     save_handler(self, fp, filename)
#
# During handling of the above exception, another exception occurred:
#
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel/iostream.py", line 207, in schedule
#     f()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/Image.py", line 2134, in save
#     save_handler(self, fp, filename)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/Image.py", line 2134, in save
#     save_handler(self, fp, filename)
#   File "<ipython-input-2-e428310e530e>", line 30, in delabeler
#     temp_img.save(root_path+random_file_name)
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/Image.py", line 2134, in save
#     save_handler(self, fp, filename)
#   File "<ipython-input-2-e428310e530e>", line 30, in delabeler
#     temp_img.save(root_path+random_file_name)
#   File "<ipython-input-2-e428310e530e>", line 30, in delabeler
#     temp_img.save(root_path+random_file_name)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/Image.py", line 2134, in save
#     save_handler(self, fp, filename)
# AttributeError: '_idat' object has no attribute 'fileno'
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/Image.py", line 2134, in save
#     save_handler(self, fp, filename)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/PngImagePlugin.py", line 1291, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/PngImagePlugin.py", line 1291, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/PngImagePlugin.py", line 1291, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/PngImagePlugin.py", line 1291, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/PngImagePlugin.py", line 1291, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel/iostream.py", line 214, in <lambda>
#     self.schedule(lambda : self._really_send(*args, **kwargs))
#   File "<ipython-input-2-e428310e530e>", line 30, in delabeler
#     temp_img.save(root_path+random_file_name)
#   File "<ipython-input-2-e428310e530e>", line 30, in delabeler
#     temp_img.save(root_path+random_file_name)
# AttributeError: '_idat' object has no attribute 'fileno'
#   File "<ipython-input-2-e428310e530e>", line 30, in delabeler
#     temp_img.save(root_path+random_file_name)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/PngImagePlugin.py", line 1291, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-2-e428310e530e>", line 30, in delabeler
#     temp_img.save(root_path+random_file_name)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/PngImagePlugin.py", line 1291, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/Image.py", line 2134, in save
#     save_handler(self, fp, filename)
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/PngImagePlugin.py", line 1291, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/Image.py", line 2134, in save
#     save_handler(self, fp, filename)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/Image.py", line 2134, in save
#     save_handler(self, fp, filename)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "<ipython-input-2-e428310e530e>", line 30, in delabeler
#     temp_img.save(root_path+random_file_name)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/PngImagePlugin.py", line 1291, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/PngImagePlugin.py", line 1291, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 510, in _save
#     l, s, d = e.encode(bufsize)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 510, in _save
#     l, s, d = e.encode(bufsize)
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 510, in _save
#     l, s, d = e.encode(bufsize)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 510, in _save
#     l, s, d = e.encode(bufsize)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "<ipython-input-2-e428310e530e>", line 30, in delabeler
#     temp_img.save(root_path+random_file_name)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel/iostream.py", line 230, in _really_send
#     ctx.term()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/Image.py", line 2134, in save
#     save_handler(self, fp, filename)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/Image.py", line 2134, in save
#     save_handler(self, fp, filename)
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/Image.py", line 2134, in save
#     save_handler(self, fp, filename)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 510, in _save
#     l, s, d = e.encode(bufsize)
#   File "<ipython-input-2-e428310e530e>", line 30, in delabeler
#     temp_img.save(root_path+random_file_name)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-2-e428310e530e>", line 30, in delabeler
#     temp_img.save(root_path+random_file_name)
#   File "<ipython-input-2-e428310e530e>", line 30, in delabeler
#     temp_img.save(root_path+random_file_name)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/Image.py", line 2134, in save
#     save_handler(self, fp, filename)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/PngImagePlugin.py", line 1291, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 510, in _save
#     l, s, d = e.encode(bufsize)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 510, in _save
#     l, s, d = e.encode(bufsize)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/PngImagePlugin.py", line 1291, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/PngImagePlugin.py", line 1291, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/Image.py", line 2134, in save
#     save_handler(self, fp, filename)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 510, in _save
#     l, s, d = e.encode(bufsize)
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 510, in _save
#     l, s, d = e.encode(bufsize)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-e428310e530e>", line 30, in delabeler
#     temp_img.save(root_path+random_file_name)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-e428310e530e>", line 30, in delabeler
#     temp_img.save(root_path+random_file_name)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/Image.py", line 2134, in save
#     save_handler(self, fp, filename)
# KeyboardInterrupt
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/PngImagePlugin.py", line 1291, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/PngImagePlugin.py", line 1291, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#   File "zmq/backend/cython/context.pyx", line 91, in zmq.backend.cython.context.Context.term
# Traceback (most recent call last):
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/PngImagePlugin.py", line 1291, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
# KeyboardInterrupt
#   File "<ipython-input-2-e428310e530e>", line 30, in delabeler
#     temp_img.save(root_path+random_file_name)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/Image.py", line 2134, in save
#     save_handler(self, fp, filename)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/Image.py", line 2134, in save
#     save_handler(self, fp, filename)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/PngImagePlugin.py", line 1291, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/Image.py", line 2134, in save
#     save_handler(self, fp, filename)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 510, in _save
#     l, s, d = e.encode(bufsize)
# KeyboardInterrupt
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 510, in _save
#     l, s, d = e.encode(bufsize)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 510, in _save
#     l, s, d = e.encode(bufsize)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-2-e428310e530e>", line 30, in delabeler
#     temp_img.save(root_path+random_file_name)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/PngImagePlugin.py", line 1291, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/Image.py", line 2134, in save
#     save_handler(self, fp, filename)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/Image.py", line 2134, in save
#     save_handler(self, fp, filename)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/PngImagePlugin.py", line 1291, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "zmq/backend/cython/checkrc.pxd", line 13, in zmq.backend.cython.checkrc._check_rc
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 510, in _save
#     l, s, d = e.encode(bufsize)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 510, in _save
#     l, s, d = e.encode(bufsize)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 510, in _save
#     l, s, d = e.encode(bufsize)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/PngImagePlugin.py", line 1291, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/PngImagePlugin.py", line 1291, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/Image.py", line 2134, in save
#     save_handler(self, fp, filename)
#   File "<ipython-input-2-e428310e530e>", line 30, in delabeler
#     temp_img.save(root_path+random_file_name)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 510, in _save
#     l, s, d = e.encode(bufsize)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/PngImagePlugin.py", line 1291, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
# KeyboardInterrupt
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
# ...
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#   File "<ipython-input-2-e428310e530e>", line 30, in delabeler
#     temp_img.save(root_path+random_file_name)
# KeyboardInterrupt
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/PngImagePlugin.py", line 1291, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
# KeyboardInterrupt
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/PngImagePlugin.py", line 1291, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/Image.py", line 2134, in save
#     save_handler(self, fp, filename)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/PngImagePlugin.py", line 1291, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 510, in _save
#     l, s, d = e.encode(bufsize)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 510, in _save
#     l, s, d = e.encode(bufsize)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 510, in _save
#     l, s, d = e.encode(bufsize)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 510, in _save
#     l, s, d = e.encode(bufsize)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 510, in _save
#     l, s, d = e.encode(bufsize)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/Image.py", line 2134, in save
#     save_handler(self, fp, filename)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 510, in _save
#     l, s, d = e.encode(bufsize)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 510, in _save
#     l, s, d = e.encode(bufsize)
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/PngImagePlugin.py", line 1291, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 510, in _save
#     l, s, d = e.encode(bufsize)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/PngImagePlugin.py", line 1291, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 510, in _save
#     l, s, d = e.encode(bufsize)
# KeyboardInterrupt
#   File "/home/dksingh/anaconda3/envs/dev/lib/python3.7/site-packages/PIL/ImageFile.py", line 510, in _save
#     l, s, d = e.encode(bufsize)
# KeyboardInterrupt
# KeyboardInterrupt
# saved: 14ff34a2bba911eaaef0ac1f6b21d262__0.png
# saved: 15eb053abba911eabc6aac1f6b21d262__0.png
# saved: 162b7c6ebba911eaa159ac1f6b21d262__0.png
# saved: 15ebf5b2bba911ea93efac1f6b21d262__0.pngsaved: 166e99a4bba911eaa4ddac1f6b21d262__0.png
#
# saved: 1708baacbba911eaaef0ac1f6b21d262__32.png
# saved: 16996328bba911eaaa56ac1f6b21d262__0.png
# saved: 17df5b66bba911eabc6aac1f6b21d262__32.png
# saved: 1825fe18bba911eaa4ddac1f6b21d262__33.png
# saved: 182b91d4bba911ea93efac1f6b21d262__32.png
# saved: 1882ed1cbba911eaaef0ac1f6b21d262__33.png
# saved: 180022e2bba911eaa159ac1f6b21d262__32.pngsaved: 18e46f92bba911eaaa56ac1f6b21d262__33.png
#
# saved: 1a260bd6bba911eaaef0ac1f6b21d262__6.pngsaved: 17437534bba911ea96ceac1f6b21d262__0.png
# saved: 16aa3d74bba911eab96eac1f6b21d262__0.pngsaved: 1954fb90bba911eaa4ddac1f6b21d262__32.pngsaved: 192cc256bba911eabc6aac1f6b21d262__33.png
#
#
# saved: 16aad8babba911eaa524ac1f6b21d262__0.png
#
# saved: 16a996a8bba911eabad2ac1f6b21d262__0.png
# saved: 19a6bcd2bba911ea93efac1f6b21d262__33.pngsaved: 1abfdebebba911eaaef0ac1f6b21d262__8.png
#
# saved: 17440b8ebba911ea9ab1ac1f6b21d262__0.pngsaved: 1ad8ebf2bba911eaa4ddac1f6b21d262__8.png
#
# saved: 1ae793bebba911eabc6aac1f6b21d262__6.png
# saved: 1a97e9aebba911eaa159ac1f6b21d262__33.pngsaved: 1b3dac22bba911ea93efac1f6b21d262__6.png
#
# saved: 1b5451f2bba911eaaef0ac1f6b21d262__9.png
# saved: 1b78e38cbba911eaa4ddac1f6b21d262__11.png
# saved: 1b914256bba911eabc6aac1f6b21d262__8.pngsaved: 172009a0bba911eaa6afac1f6b21d262__0.png
